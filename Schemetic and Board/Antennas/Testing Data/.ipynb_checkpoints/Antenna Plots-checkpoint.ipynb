# %%
import skrf as rf
from skrf import NetworkSet
from skrf import plotting
from skrf.plotting import save_all_figs

# %matplotlib inline
from pylab import *
rf.stylely()

# %%
antennas_dict = rf.read_all('.', contains='ant')
sim_dict = rf.read_all('.', contains='sim')

# %%
antennas = NetworkSet(antennas_dict)
sim = NetworkSet(sim_dict)

resonant_points = []
for a in antennas:
    resonant_points.append(argmin(abs(a.s)))

# %%
s11_all = plt.figure()
s11_all.suptitle("S11 for all antennas")
s11_all.set_label("S11 for all antennas")
for i in range(0, len(antennas)):
    antennas[i].frequency.unit = 'GHz'
    print(antennas[i].z[resonant_points[i]])
    antennas[i].plot_s_db()

ylim([-25, 5])
    

s11_uncert = plt.figure()
s11_uncert.suptitle("S11 of all antennas with uncertainty")

antennas.plot_uncertainty_bounds_s_db(label='S11');
sim[0].plot_s_db()
ylim([-25, 5])
save_all_figs('.', format=['png'])
# Out:
# [[ 61.13497905+7.96144728j]]
# [[ 57.47953918+7.30397488j]]
# [[ 58.52209826+9.09004435j]]
# [[ 57.73085514+6.93119315j]]
# [[ 59.01851662+9.87485562j]]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4842: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[0] = start
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4843: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[N + 1] = end
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4846: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[1:N + 1, 1] = y1slice
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4848: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[N + 2:, 1] = y2slice[::-1]
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ./unnamedPlot.png
# ./unnamedPlot.png

# %%
for a in antennas:
    a.plot_s_smith(draw_labels=True)

save_all_figs('.', format=['png'])
# Out:
# ./unnamedPlot.png
